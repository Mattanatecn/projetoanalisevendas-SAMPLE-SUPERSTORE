# %%
import pandas as pd

# %% [markdown]
# # Análise Final-Sample Superstore
#
# ## 1.Carregamento da base tratada

# %%
def carregar_dados(caminho):
    dados=pd.read_csv(caminho,encoding='utf-8',parse_dates=['Order Date', 'Ship Date'])
    return dados

# %%
caminho='../dados/tratado/superstore_tratado.csv'
df=carregar_dados(caminho)

# %%
print(f'quantidade de linhas {len(df)}')
print(f'quantidade de colunas {len(df.columns)}')
# Out:
# quantidade de linhas 9994
# quantidade de colunas 26

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   str
#  2   Order Date      9994 non-null   datetime64[us]
#  3   Ship Date       9994 non-null   datetime64[us]
#  4   Ship Mode       9994 non-null   str
#  5   Customer ID     9994 non-null   str
#  6   Customer Name   9994 non-null   str
#  7   Segment         9994 non-null   str
#  8   Country         9994 non-null   str
#  9   City            9994 non-null   str
#  10  State           9994 non-null   str
#  11  Postal Code     9994 non-null   int64
#  12  Region          9994 non-null   str
#  13  Product ID      9994 non-null   str
#  14  Category        9994 non-null   str
#  15  Sub-Category    9994 non-null   str
#  16  Product Name    9994 non-null   str
#  17  Sales           9994 non-null   float64
#  18  Quantity        9994 non-null   int64
#  19  Discount        9994 non-null   float64
#  20  Profit          9994 non-null   float64
#  21  dias_envio      9994 non-null   int64
#  22  ano             9994 non-null   int64
#  23  mes             9994 non-null   int64
#  24  margem_lucro    9994 non-null   float64
#  25  faixa_desconto  9994 non-null   str
# dtypes: datetime64[us](2), float64(4), int64(6), str(14)
# memory usage: 3.7 MB

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#                                         Product Name     Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600        2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400        3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200        2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775        5
# 4                     Eldon Fold 'N Roll Cart System   22.3680        2
#
#   Discount    Profit dias_envio   ano  mes  margem_lucro      faixa_desconto
# 0     0.00   41.9136          3  2016   11        0.1600        sem desconto
# 1     0.00  219.5820          3  2016   11        0.3000        sem desconto
# 2     0.00    6.8714          4  2016    6        0.4700        sem desconto
# 3     0.45 -383.0310          7  2015   10       -0.4000  desconto agressivo
# 4     0.20    2.5164          7  2015   10        0.1125       desconto alto
#
# [5 rows x 26 columns]

# %% [markdown]
# ## 2.Validação da base tratada
#
# Nesta etapa, verificamos se a base gerada pelo processo de limpeza está pronta para a análise.

# %%
nulo=df.isnull().sum()
print(f'Dados nulos por coluna:{nulo}')
# Out:
# Dados nulos por coluna:Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code       0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# dias_envio        0
# ano               0
# mes               0
# margem_lucro      0
# faixa_desconto    0
# dtype: int64

# %%
duplicado=df.duplicated().sum()
print(f'Linhas duplicadas: {duplicado}')
# Out:
# Linhas duplicadas: 0

# %%
data_inicial=df['Order Date'].min()
data_final=df['Order Date'].max()
print(f'menor data pedido:{data_inicial}')
print(f'maior data pedido:{data_final}')
# Out:
# menor data pedido:2014-01-03 00:00:00
# maior data pedido:2017-12-30 00:00:00

# %%
desconto=df['Discount']
minimodesconto=desconto.min()
maximodesconto=desconto.max()
print(f'menor desconto:{minimodesconto}')
print(f'maior desconto:{maximodesconto}')
# Out:
# menor desconto:0.0
# maior desconto:0.8

# %%
prazo_envio=df['dias_envio']
prazominimo=prazo_envio.min()
prazomaximo=prazo_envio.max()
print(f'menor prazo de envio:{prazominimo}')
print(f'maior prazo de envio:{prazomaximo}')
# Out:
# menor prazo de envio:0
# maior prazo de envio:7

# %%
anos=df['ano']
listaanos=sorted(set(anos))
for i in listaanos:
    print(i)
# Out:
# 2014
# 2015
# 2016
# 2017

# %%
faixadesconto=df['faixa_desconto']
listadesconto=set(faixadesconto)
for i in listadesconto:
    print(i)
# Out:
# desconto baixo
# desconto alto
# desconto agressivo
# sem desconto

# %% [markdown]
# ## 3. Visão geral do negócio

# %%
def calcular_kpis(dados):
    faturamento=dados['Sales'].sum()
    lucrototal=dados['Profit'].sum()
    margemglobal=lucrototal/faturamento
    quantidadevendida=dados['Quantity'].sum()
    totalpedidos=dados['Order ID'].nunique()
    ticketmedio=faturamento/totalpedidos

    kpis={
    'faturamento_total': faturamento,
    'lucro_total': lucrototal,
    'margem_global': margemglobal,
    'quantidade_vendida': quantidadevendida,
    'total_pedidos': totalpedidos,
    'ticket_medio': ticketmedio
    }

    return kpis

# %%
kpis=calcular_kpis(df)

print(f"Faturamento total: US$ {kpis['faturamento_total']:.2f}")
print(f"Lucro total: US$ {kpis['lucro_total']:.2f}")
print(f"Margem global: {kpis['margem_global']:.2%}")
print(f"Quantidade vendida: {kpis['quantidade_vendida']:}")
print(f"Total de pedidos: {kpis['total_pedidos']:}")
print(f"Ticket médio: US$ {kpis['ticket_medio']:.2f}")
# Out:
# Faturamento total: US$ 2297200.86
# Lucro total: US$ 286397.02
# Margem global: 12.47%
# Quantidade vendida: 37873
# Total de pedidos: 5009
# Ticket médio: US$ 458.61

# %% [markdown]
# ### Interpretação dos KPIs
#
# A empresa apresentou lucro no período analisado. O faturamento foi de aproximadamente US$ 2.30 milhões, com lucro total de US$ 286,40 mil.
#
# A margem global foi de 12,47%. Isso significa que, para cada US$ 100 faturados, aproximadamente US$ 12,47 permaneceram como lucro.
#
# O ticket médio foi de US$ 458,61. Isso representa o valor médio faturado por pedido, considerando os 5.009 pedidos únicos registrados na base.
#
# Apesar do resultado geral positivo, ainda é necessário investigar se existem categorias, regiões ou períodos com baixa lucratividade ou prejuízo assim como foi feito na exploração inicial onde achamos categorias com prejuizo.

# %% [markdown]
# ## 4. Análise temporal
#
# ### 4.1 Desempenho anual

# %%
def resumir_por_grupo(dados, coluna_grupo):
    resumo=dados.groupby(coluna_grupo).agg(
        faturamento_total=('Sales','sum'),
        lucro_total=('Profit','sum'),
        quantidade_vendida=('Quantity','sum'),
        total_pedidos=('Order ID','nunique'),
    )
    resumo['margem_global']=(
        resumo['lucro_total']/resumo['faturamento_total']
    )
    resumo['ticket_medio']=(
        resumo['faturamento_total']/resumo['total_pedidos']
    )
    return resumo

def variacoes_temporais(resumo):
    resumo_temporal=resumo.copy()
    resumo_temporal['variacao_faturamento']=(
        resumo_temporal['faturamento_total'].pct_change()
    )
    resumo_temporal['variacao_lucro']=(
        resumo_temporal['lucro_total'].pct_change()
    )
    return resumo_temporal

resumo_anual_base=resumir_por_grupo(df, 'ano')
resumo_anual=variacoes_temporais(resumo_anual_base)
resumo_anual
# Out:
#       faturamento_total  lucro_total  quantidade_vendida  total_pedidos  \
# ano
# 2014        484247.4981   49543.9741                7581            969
# 2015        470532.5090   61618.6037                7979           1038
# 2016        609205.5980   81795.1743                9837           1315
# 2017        733215.2552   93439.2696               12476           1687
#
#       margem_global  ticket_medio  variacao_faturamento  variacao_lucro
# ano
# 2014       0.102311    499.739420                   NaN             NaN
# 2015       0.130955    453.306849             -0.028322        0.243715
# 2016       0.134265    463.274219              0.294715        0.327443
# 2017       0.127438    434.626707              0.203560        0.142357

# %% [markdown]
# ### Interpretação do resumo anual
#
# O ano de 2016 apresentou a maior margem global, com 13,43%, enquanto 2014 teve a menor margem, com 10,23%.
#
# Em 2015, o faturamento foi menor do que em 2014. Mesmo assim, o lucro aumentou e a margem passou de 10,23% para 13,10%. Isso indica uma melhora na eficiência financeira das vendas realizadas naquele ano.
#
# Ainda é necessário investigar quais fatores contribuíram para essa melhora, como descontos, categorias vendidas ou desempenho regional.
#
# A quantidade vendida aumentou em todos os anos. Em 2015, foram vendidas mais unidades do que em 2014, mas o faturamento foi o menor de todo o período analisado.
#
# Isso indica que o aumento no volume de produtos vendidos não resultou em crescimento do faturamento. Uma possível explicação é a venda de produtos com menor valor médio ou uma mudança no comportamento dos descontos, hipóteses que ainda precisam ser investigadas.
#
# O ticket médio caiu de US$ 499,74 em 2014 para US$ 453,31 em 2015. Isso reforça a conclusão de que, apesar do aumento no número de pedidos e na quantidade vendida, cada pedido gerou menos faturamento em média.
#
# Em 2017, o ticket médio foi ainda menor, com US$ 434,63. Mesmo assim, o ano apresentou o maior faturamento do período, sustentado pelo aumento expressivo no número de pedidos e na quantidade vendida.
#
# Esses resultados mostram que o crescimento do faturamento pode vir do aumento do volume de pedidos, mesmo quando o valor médio de cada pedido diminui.
#
# variação faturamento:
# 2015: queda de 2,83%
# 2016: crescimento de 29,47%
# 2017: crescimento de 20,36%
#
# variação de lucro:
# 2015: crescimento de 24,37%
# 2016: crescimento de 32,74%
# 2017: crescimento de 14,24%
#
# Em 2015, o faturamento caiu 2,83%, mas o lucro cresceu 24,37%. Esse contraste reforça que houve melhora na eficiência financeira, embora a causa ainda precise ser investigada.
#
# Em 2016, o lucro cresceu 32,74%, superando o crescimento de 29,47% do faturamento. Como o lucro avançou mais rapidamente, a margem global aumentou.
#
# Em 2017, o faturamento cresceu 20,36%, enquanto o lucro cresceu apenas 14,24%. Como o lucro avançou mais lentamente que o faturamento, a margem global diminuiu.

# %%
formatacao_resumo={
    'faturamento_total': 'US$ {:,.2f}',
    'lucro_total': 'US$ {:,.2f}',
    'quantidade_vendida': '{:,.0f}',
    'total_pedidos': '{:,.0f}',
    'margem_global': '{:.2%}',
    'ticket_medio': 'US$ {:,.2f}',
    'variacao_faturamento': '{:.2%}',
    'variacao_lucro': '{:.2%}'
}


resumo_anual_formatado=resumo_anual.style.format(
    formatacao_resumo,
    na_rep='-',
    decimal=',',
    thousands='.'
)


resumo_anual_formatado
# Out:
# <style type="text/css">
# </style>
# <table id="T_80639">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80639_level0_col0" class="col_heading level0 col0" >faturamento_total</th>
#       <th id="T_80639_level0_col1" class="col_heading level0 col1" >lucro_total</th>
#       <th id="T_80639_level0_col2" class="col_heading level0 col2" >quantidade_vendida</th>
#       <th id="T_80639_level0_col3" class="col_heading level0 col3" >total_pedidos</th>
#       <th id="T_80639_level0_col4" class="col_heading level0 col4" >margem_global</th>
#       <th id="T_80639_level0_col5" class="col_heading level0 col5" >ticket_medio</th>
#       <th id="T_80639_level0_col6" class="col_heading level0 col6" >variacao_faturamento</th>
#       <th id="T_80639_level0_col7" class="col_heading level0 col7" >variacao_lucro</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ano</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80639_level0_row0" class="row_heading level0 row0" >2014</th>
#       <td id="T_80639_row0_col0" class="data row0 col0" >US$ 484.247,50</td>
#       <td id="T_80639_row0_col1" class="data row0 col1" >US$ 49.543,97</td>
#       <td id="T_80639_row0_col2" class="data row0 col2" >7.581</td>
#       <td id="T_80639_row0_col3" class="data row0 col3" >969</td>
#       <td id="T_80639_row0_col4" class="data row0 col4" >10,23%</td>
#       <td id="T_80639_row0_col5" class="data row0 col5" >US$ 499,74</td>
#       <td id="T_80639_row0_col6" class="data row0 col6" >-</td>
#       <td id="T_80639_row0_col7" class="data row0 col7" >-</td>
#     </tr>
#     <tr>
#       <th id="T_80639_level0_row1" class="row_heading level0 row1" >2015</th>
#       <td id="T_80639_row1_col0" class="data row1 col0" >US$ 470.532,51</td>
#       <td id="T_80639_row1_col1" class="data row1 col1" >US$ 61.618,60</td>
#       <td id="T_80639_row1_col2" class="data row1 col2" >7.979</td>
#       <td id="T_80639_row1_col3" class="data row1 col3" >1.038</td>
#       <td id="T_80639_row1_col4" class="data row1 col4" >13,10%</td>
#       <td id="T_80639_row1_col5" class="data row1 col5" >US$ 453,31</td>
#       <td id="T_80639_row1_col6" class="data row1 col6" >-2,83%</td>
#       <td id="T_80639_row1_col7" class="data row1 col7" >24,37%</td>
#     </tr>
#     <tr>
#       <th id="T_80639_level0_row2" class="row_heading level0 row2" >2016</th>
#       <td id="T_80639_row2_col0" class="data row2 col0" >US$ 609.205,60</td>
#       <td id="T_80639_row2_col1" class="data row2 col1" >US$ 81.795,17</td>
#       <td id="T_80639_row2_col2" class="data row2 col2" >9.837</td>
#       <td id="T_80639_row2_col3" class="data row2 col3" >1.315</td>
#       <td id="T_80639_row2_col4" class="data row2 col4" >13,43%</td>
#       <td id="T_80639_row2_col5" class="data row2 col5" >US$ 463,27</td>
#       <td id="T_80639_row2_col6" class="data row2 col6" >29,47%</td>
#       <td id="T_80639_row2_col7" class="data row2 col7" >32,74%</td>
#     </tr>
#     <tr>
#       <th id="T_80639_level0_row3" class="row_heading level0 row3" >2017</th>
#       <td id="T_80639_row3_col0" class="data row3 col0" >US$ 733.215,26</td>
#       <td id="T_80639_row3_col1" class="data row3 col1" >US$ 93.439,27</td>
#       <td id="T_80639_row3_col2" class="data row3 col2" >12.476</td>
#       <td id="T_80639_row3_col3" class="data row3 col3" >1.687</td>
#       <td id="T_80639_row3_col4" class="data row3 col4" >12,74%</td>
#       <td id="T_80639_row3_col5" class="data row3 col5" >US$ 434,63</td>
#       <td id="T_80639_row3_col6" class="data row3 col6" >20,36%</td>
#       <td id="T_80639_row3_col7" class="data row3 col7" >14,24%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 4.2 Desempenho mensal

# %%
resumo_mensal_base=resumir_por_grupo(
    df,
    ['ano','mes']
)

resumo_mensal_base

resumo_mensal=resumo_mensal_base.copy()
resumo_mensal['variacao_faturamento']=(
    resumo_mensal['faturamento_total'].pct_change()
)

resumo_mensal['diferenca_lucro']=(
    resumo_mensal['lucro_total'].diff()
)

resumo_mensal
# Out:
#           faturamento_total  lucro_total  quantidade_vendida  total_pedidos  \
# ano  mes
# 2014 1           14236.8950    2450.1907                 284             32
#      2            4519.8920     862.3084                 159             28
#      3           55691.0090     498.7299                 585             71
#      4           28295.3450    3488.8352                 536             66
#      5           23648.2870    2738.7096                 466             69
#      6           34595.1276    4976.5244                 521             66
#      7           33946.3930    -841.4826                 550             65
#      8           27909.4685    5318.1050                 609             72
#      9           81777.3508    8328.0994                1000            130
#      10          31453.3930    3448.2573                 573             78
#      11          78628.7167    9292.1269                1219            151
#      12          69545.6205    8983.5699                1079            141
# 2015 1           18174.0756   -3281.0070                 236             29
#      2           11951.4110    2813.8508                 239             36
#      3           38726.2520    9732.0978                 515             79
#      4           34195.2085    4187.4962                 543             72
#      5           30131.6865    4667.8690                 575             74
#      6           24797.2920    3335.5572                 486             68
#      7           28765.3250    3288.6483                 557             66
#      8           36898.3322    5355.8084                 598             68
#      9           64595.9180    8209.1627                1086            140
#      10          31404.9235    2817.3660                 631             87
#      11          75972.5635   12474.7884                1310            158
#      12          74919.5212    8016.9659                1203            161
# 2016 1           18542.4910    2824.8233                 358             48
#      2           22978.8150    5004.5795                 306             45
#      3           51715.8750    3611.9680                 579             86
#      4           38750.0390    2977.8149                 635             89
#      5           56987.7280    8662.1464                 863            108
#      6           40344.5340    4750.3781                 742             97
#      7           39261.9630    4432.8779                 758             96
#      8           31115.3743    2062.0693                 693             90
#      9           73410.0249    9328.6576                1316            192
#      10          59687.7450   16243.1425                 767            105
#      11          79411.9658    4011.4075                1406            183
#      12          96999.0430   17885.3093                1414            176
# 2017 1           43971.3740    7140.4391                 597             69
#      2           20301.1334    1613.8720                 363             53
#      3           58872.3528   14751.8915                 885            118
#      4           36521.5361     933.2900                 733            116
#      5           44261.1102    6342.5828                 887            118
#      6           52981.7257    8223.3357                 931            133
#      7           45264.4160    6952.6212                 840            111
#      8           63120.8880    9040.9557                 884            111
#      9           87866.6520   10991.5556                1660            226
#      10          77776.9232    9275.2755                1133            147
#      11         118447.8250    9690.1037                1840            261
#      12          83829.3188    8483.3468                1723            224
#
#           margem_global  ticket_medio  variacao_faturamento  diferenca_lucro
# ano  mes
# 2014 1         0.172101    444.902969                   NaN              NaN
#      2         0.190781    161.424714             -0.682523       -1587.8823
#      3         0.008955    784.380408             11.321314        -363.5785
#      4         0.123301    428.717348             -0.491923        2990.1053
#      5         0.115810    342.728797             -0.164234        -750.1256
#      6         0.143850    524.168600              0.462902        2237.8148
#      7        -0.024789    522.252200             -0.018752       -5818.0070
#      8         0.190548    387.631507             -0.177837        6159.5876
#      9         0.101839    629.056545              1.930093        3009.9944
#      10        0.109631    403.248628             -0.615378       -4879.8421
#      11        0.118177    520.719978              1.499848        5843.8696
#      12        0.129175    493.231351             -0.115519        -308.5570
# 2015 1        -0.180532    626.692262             -0.738674      -12264.5769
#      2         0.235441    331.983639             -0.342392        6094.8578
#      3         0.251305    490.205722              2.240308        6918.2470
#      4         0.122459    474.933451             -0.117002       -5544.6016
#      5         0.154916    407.184953             -0.118833         480.3728
#      6         0.134513    364.666059             -0.177036       -1332.3118
#      7         0.114327    435.838258              0.160019         -46.9089
#      8         0.145150    542.622532              0.282736        2067.1601
#      9         0.127085    461.399414              0.750646        2853.3543
#      10        0.089711    360.976132             -0.513825       -5391.7967
#      11        0.164201    480.839009              1.419129        9657.4224
#      12        0.107008    465.338641             -0.013861       -4457.8225
# 2016 1         0.152343    386.301896             -0.752501       -5192.1426
#      2         0.217791    510.640333              0.239252        2179.7562
#      3         0.069843    601.347384              1.250589       -1392.6115
#      4         0.076847    435.393697             -0.250713        -634.1531
#      5         0.152000    527.664148              0.470650        5684.3315
#      6         0.117745    415.923031             -0.292049       -3911.7683
#      7         0.112905    408.978781             -0.026833        -317.5002
#      8         0.066272    345.726381             -0.207493       -2370.8086
#      9         0.127076    382.343880              1.359285        7266.5883
#      10        0.272135    568.454714             -0.186927        6914.4849
#      11        0.050514    433.945168              0.330457      -12231.7350
#      12        0.184386    551.130926              0.221466       13873.9018
# 2017 1         0.162388    637.266290             -0.546682      -10744.8702
#      2         0.079497    383.040253             -0.538310       -5526.5671
#      3         0.250574    498.918244              1.899954       13138.0195
#      4         0.025555    314.840828             -0.379649      -13818.6015
#      5         0.143299    375.094154              0.211918        5409.2928
#      6         0.155211    398.358840              0.197027        1880.7529
#      7         0.153600    407.787532             -0.145660       -1270.7145
#      8         0.143232    568.656649              0.394492        2088.3345
#      9         0.125094    388.790496              0.392038        1950.5999
#      10        0.119255    529.094716             -0.114830       -1716.2801
#      11        0.081809    453.823084              0.522917         414.8282
#      12        0.101198    374.238030             -0.292268       -1206.7569

# %%
formatacao_resumo_mensal={
    'faturamento_total': 'US$ {:,.2f}',
    'lucro_total': 'US$ {:,.2f}',
    'quantidade_vendida': '{:,.0f}',
    'total_pedidos': '{:,.0f}',
    'margem_global': '{:.2%}',
    'ticket_medio': 'US$ {:,.2f}',
    'variacao_faturamento': '{:.2%}',
    'diferenca_lucro': 'US$ {:,.2f}'
}

resumo_mensal_formatado=resumo_mensal.style.format(
    formatacao_resumo_mensal,
    na_rep='-',
    decimal=',',
    thousands='.'
)

resumo_mensal_formatado
# Out:
# <style type="text/css">
# </style>
# <table id="T_3c3be">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c3be_level0_col0" class="col_heading level0 col0" >faturamento_total</th>
#       <th id="T_3c3be_level0_col1" class="col_heading level0 col1" >lucro_total</th>
#       <th id="T_3c3be_level0_col2" class="col_heading level0 col2" >quantidade_vendida</th>
#       <th id="T_3c3be_level0_col3" class="col_heading level0 col3" >total_pedidos</th>
#       <th id="T_3c3be_level0_col4" class="col_heading level0 col4" >margem_global</th>
#       <th id="T_3c3be_level0_col5" class="col_heading level0 col5" >ticket_medio</th>
#       <th id="T_3c3be_level0_col6" class="col_heading level0 col6" >variacao_faturamento</th>
#       <th id="T_3c3be_level0_col7" class="col_heading level0 col7" >diferenca_lucro</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ano</th>
#       <th class="index_name level1" >mes</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c3be_level0_row0" class="row_heading level0 row0" rowspan="12">2014</th>
#       <th id="T_3c3be_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_3c3be_row0_col0" class="data row0 col0" >US$ 14.236,90</td>
#       <td id="T_3c3be_row0_col1" class="data row0 col1" >US$ 2.450,19</td>
#       <td id="T_3c3be_row0_col2" class="data row0 col2" >284</td>
#       <td id="T_3c3be_row0_col3" class="data row0 col3" >32</td>
#       <td id="T_3c3be_row0_col4" class="data row0 col4" >17,21%</td>
#       <td id="T_3c3be_row0_col5" class="data row0 col5" >US$ 444,90</td>
#       <td id="T_3c3be_row0_col6" class="data row0 col6" >-</td>
#       <td id="T_3c3be_row0_col7" class="data row0 col7" >-</td>
#     </tr>
#     <tr>
#       <th id="T_3c3be_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_3c3be_row1_col0" class="data row1 col0" >US$ 4.519,89</td>
#       <td id="T_3c3be_row1_col1" class="data row1 col1" >US$ 862,31</td>
#       <td id="T_3c3be_row1_col2" class="data row1 col2" >159</td>
#       <td id="T_3c3be_row1_col3" class="data row1 col3" >28</td>
#       <td id="T_3c3be_row1_col4" class="data row1 col4" >19,08%</td>
#       <td id="T_3c3be_row1_col5" class="data row1 col5" >US$ 161,42</td>
#       <td id="T_3c3be_row1_col6" class="data row1 col6" >-68,25%</td>
#       <td id="T_3c3be_row1_col7" class="data row1 col7" >US$ -1.587,88</td>
#     </tr>
#     <tr>
#       <th id="T_3c3be_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_3c3be_row2_col0" class="data row2 col0" >US$ 55.691,01</td>
#       <td id="T_3c3be_row2_col1" class="data row2 col1" >US$ 498,73</td>
#       <td id="T_3c3be_row2_col2" class="data row2 col2" >585</td>
#       <td id="T_3c3be_row2_col3" class="data row2 col3" >71</td>
#       <td id="T_3c3be_row2_col4" class="data row2 col4" >0,90%</td>
#       <td id="T_3c3be_row2_col5" class="data row2 col5" >US$ 784,38</td>
#       <td id="T_3c3be_row2_col6" class="data row2 col6" >1132,13%</td>
#       <td id="T_3c3be_row2_col7" class="data row2 col7" >US$ -363,58</td>
#     </tr>
#     <tr>
#       <th id="T_3c3be_level1_row3" class="row_heading level1 row3" >4</th>
#       <td id="T_3c3be_row3_col0" class="data row3 col0" >US$ 28.295,35</td>
#       <td id="T_3c3be_row3_col1" class="data row3 col1" >US$ 3.488,84</td>
#       <td id="T_3c3be_row3_col2" class="data row3 col2" >536</td>
#       <td id="T_3c3be_row3_col3" class="data row3 col3" >66</td>
#       <td id="T_3c3be_row3_col4" class="data row3 col4" >12,33%</td>
#       <td id="T_3c3be_row3_col5" class="data row3 col5" >US$ 428,72</td>
#       <td id="T_3c3be_row3_col6" class="data row3 col6" >-49,19%</td>
#       <td id="T_3c3be_row3_col7" class="data row3 col7" >US$ 2.990,11</td>
#     </tr>
#     <tr>
#       <th id="T_3c3be_level1_row4" class="row_heading level1 row4" >5</th>
#       <td id="T_3c3be_row4_col0" class="data row4 col0" >US$ 23.648,29</td>
#       <td id="T_3c3be_row4_col1" class="data row4 col1" >US$ 2.738,71</td>
#       <td id="T_3c3be_row4_col2" class="data row4 col2" >466</td>
#       <td id="T_3c3be_row4_col3" class="data row4 col3" >69</td>
#       <td id="T_3c3be_row4_col4" class="data row4 col4" >11,58%</td>
#       <td id="T_3c3be_row4_col5" class="data row4 col5" >US$ 342,73</td>
#       <td id="T_3c3be_row4_col6" class="data row4 col6" >-16,42%</td>
#       <td id="T_3c3be_row4_col7" class="data row4 col7" >US$ -750,13</td>
#     </tr>
#     <tr>
#       <th id="T_3c3be_level1_row5" class="row_heading level1 row5" >6</th>
#       <td id="T_3c3be_row5_col0" class="data row5 col0" >US$ 34.595,13</td>
#       <td id="T_3c3be_row5_col1" class="data row5 col1" >US$ 4.976,52</td>
#       <td id="T_3c3be_row5_col2" class="data row5 col2" >521</td>
#       <td id="T_3c3be_row5_col3" class="data row5 col3" >66</td>
#       <td id="T_3c3be_row5_col4" class="data row5 col4" >14,39%</td>
#       <td id="T_3c3be_row5_col5" class="data row5 col5" >US$ 524,17</td>
#       <td id="T_3c3be_row5_col6" class="data row5 col6" >46,29%</td>
#       <td id="T_3c3be_row5_col7" class="data row5 col7" >US$ 2.237,81</td>
#     </tr>
#     <tr>
#       <th id="T_3c3be_level1_row6" class="row_heading level1 row6" >7</th>
#       <td id="T_3c3be_row6_col0" class="data row6 col0" >US$ 33.946,39</td>
#       <td id="T_3c3be_row6_col1" class="data row6 col1" >US$ -841,48</td>
#       <td id="T_3c3be_row6_col2" class="data row6 col2" >550</td>
#       <td id="T_3c3be_row6_col3" class="data row6 col3" >65</td>
#       <td id="T_3c3be_row6_col4" class="data row6 col4" >-2,48%</td>
#       <td id="T_3c3be_row6_col5" class="data row6 col5" >US$ 522,25</td>
#       <td id="T_3c3be_row6_col6" class="data row6 col6" >-1,88%</td>
#       <td id="T_3c3be_row6_col7" class="data row6 col7" >US$ -5.818,01</td>
#     </tr>
#     <tr>
#       <th id="T_3c3be_level1_row7" class="row_heading level1 row7" >8</th>
#       <td id="T_3c3be_row7_col0" class="data row7 col0" >US$ 27.909,47</td>
#       <td id="T_3c3be_row7_col1" class="data row7 col1" >US$ 5.318,10</td>
#       <td id="T_3c3be_row7_col2" class="data row7 col2" >609</td>
#       <td id="T_3c3be_row7_col3" class="data row7 col3" >72</td>
#       <td id="T_3c3be_row7_col4" class="data row7 col4" >19,05%</td>
#       <td id="T_3c3be_row7_col5" class="data row7 col5" >US$ 387,63</td>
#       <td id="T_3c3be_row7_col6" class="data row7 col6" >-17,78%</td>
#       <td id="T_3c3be_row7_col7" class="data row7 col7" >US$ 6.159,59</td>
#     </tr>
#     <tr>
#       <th id="T_3c3be_level1_row8" class="row_heading level1 row8" >9</th>
#       <td id="T_3c3be_row8_col0" class="data row8 col0" >US$ 81.777,35</td>
#       <td id="T_3c3be_row8_col1" class="data row8 col1" >US$ 8.328,10</td>
#       <td id="T_3c3be_row8_col2" class="data row8 col2" >1.000</td>
#       <td id="T_3c3be_row8_col3" class="data row8 col3" >130</td>
#       <td id="T_3c3be_row8_col4" class="data row8 col4" >10,18%</td>
#       <td id="T_3c3be_row8_col5" class="data row8 col5" >US$ 629,06</td>
#       <td id="T_3c3be_row8_col6" class="data row8 col6" >193,01%</td>
#       <td id="T_3c3be_row8_col7" class="data row8 col7" >US$ 3.009,99</td>
#     </tr>
#     <tr>
#       <th id="T_3c3be_level1_row9" class="row_heading level1 row9" >10</th>
#       <td id="T_3c3be_row9_col0" class="data row9 col0" >US$ 31.453,39</td>
#       <td id="T_3c3be_row9_col1" class="data row9 col1" >US$ 3.448,26</td>
#       <td id="T_3c3be_row9_col2" class="data row9 col2" >573</td>
#       <td id="T_3c3be_row9_col3" class="data row9 col3" >78</td>
#       <td id="T_3c3be_row9_col4" class="data row9 col4" >10,96%</td>
#       <td id="T_3c3be_row9_col5" class="data row9 col5" >US$ 403,25</td>
#       <td id="T_3c3be_row9_col6" class="data row9 col6" >-61,54%</td>
#       <td id="T_3c3be_row9_col7" class="dat

# %%
meses_prejuizo=resumo_mensal[
    resumo_mensal['lucro_total']<0
]

meses_prejuizo
# Out:
#           faturamento_total  lucro_total  quantidade_vendida  total_pedidos  \
# ano  mes
# 2014 7           33946.3930    -841.4826                 550             65
# 2015 1           18174.0756   -3281.0070                 236             29
#
#           margem_global  ticket_medio  variacao_faturamento  diferenca_lucro
# ano  mes
# 2014 7        -0.024789    522.252200             -0.018752       -5818.0070
# 2015 1        -0.180532    626.692262             -0.738674      -12264.5769

# %% [markdown]
# #### Meses com prejuízo
#
# Janeiro de 2015 apresentou o maior prejuízo, com aproximadamente US$ 3.281,01 negativos, e também a pior margem global, com -18,05%.
#
# Apesar de seu ticket médio de US$ 626,69 ser maior que o de julho de 2014, janeiro de 2015 teve menos pedidos, menor quantidade vendida e um prejuízo mais elevado.
#
# Isso mostra que analisar somente o ticket médio não é suficiente. Um pedido pode apresentar valor médio alto e ainda gerar prejuízo. Para avaliar o desempenho, é necessário observar também o lucro e a margem global.

# %%
ranking_lucro_mensal=resumo_mensal.sort_values(['lucro_total'])
ranking_lucro_mensal.head()
# Out:
#           faturamento_total  lucro_total  quantidade_vendida  total_pedidos  \
# ano  mes
# 2015 1           18174.0756   -3281.0070                 236             29
# 2014 7           33946.3930    -841.4826                 550             65
#      3           55691.0090     498.7299                 585             71
#      2            4519.8920     862.3084                 159             28
# 2017 4           36521.5361     933.2900                 733            116
#
#           margem_global  ticket_medio  variacao_faturamento  diferenca_lucro
# ano  mes
# 2015 1        -0.180532    626.692262             -0.738674      -12264.5769
# 2014 7        -0.024789    522.252200             -0.018752       -5818.0070
#      3         0.008955    784.380408             11.321314        -363.5785
#      2         0.190781    161.424714             -0.682523       -1587.8823
# 2017 4         0.025555    314.840828             -0.379649      -13818.6015

# %%
ranking_margem_global=resumo_mensal.sort_values(['margem_global'])
ranking_margem_global.head()
# Out:
#           faturamento_total  lucro_total  quantidade_vendida  total_pedidos  \
# ano  mes
# 2015 1           18174.0756   -3281.0070                 236             29
# 2014 7           33946.3930    -841.4826                 550             65
#      3           55691.0090     498.7299                 585             71
# 2017 4           36521.5361     933.2900                 733            116
# 2016 11          79411.9658    4011.4075                1406            183
#
#           margem_global  ticket_medio  variacao_faturamento  diferenca_lucro
# ano  mes
# 2015 1        -0.180532    626.692262             -0.738674      -12264.5769
# 2014 7        -0.024789    522.252200             -0.018752       -5818.0070
#      3         0.008955    784.380408             11.321314        -363.5785
# 2017 4         0.025555    314.840828             -0.379649      -13818.6015
# 2016 11        0.050514    433.945168              0.330457      -12231.7350

# %% [markdown]
# ### interpretação rankings
#
# Os rankings de lucro e margem são parecidos, mas respondem perguntas diferentes. Fevereiro de 2014 teve lucro total baixo principalmente por seu baixo volume de vendas, enquanto sua margem de 19,08% indica boa eficiência.
#
# Novembro de 2016 apresentou faturamento elevado, mas margem de apenas 5,05%. Isso indica que um volume financeiro relevante gerou proporcionalmente pouco lucro.
#
# Janeiro de 2015 continua sendo o mês mais crítico, pois combina o maior prejuízo com a pior margem global.

# %% [markdown]
# ## 5. Categorias e subcategorias

# %%
resumo_categoria=resumir_por_grupo(df,'Category')
resumo_categoria
# Out:
#                  faturamento_total  lucro_total  quantidade_vendida  \
# Category
# Furniture              741999.7953   18451.2728                8028
# Office Supplies        719047.0320  122490.8008               22906
# Technology             836154.0330  145454.9481                6939
#
#                  total_pedidos  margem_global  ticket_medio
# Category
# Furniture                 1764       0.024867    420.634805
# Office Supplies           3742       0.170352    192.155808
# Technology                1544       0.173957    541.550540

# %% [markdown]
# ### Interpretação por categoria
#
# Technology apresentou o maior faturamento e o maior lucro, além da melhor margem global entre as categorias.
#
# Furniture teve faturamento superior ao de Office Supplies, mas gerou muito menos lucro. Sua margem de apenas 2,49%, comparada a 17,04% de Office Supplies, indica baixa eficiência financeira.
#
# Embora Furniture seja lucrativa no resultado total, a categoria provavelmente contém subcategorias que reduzem fortemente seu desempenho.

# %%
resumo_subcategoria=resumir_por_grupo(df,'Sub-Category')
resumo_subcategoria
# Out:
#               faturamento_total  lucro_total  quantidade_vendida  \
# Sub-Category
# Accessories         167380.3180   41936.6357                2976
# Appliances          107532.1610   18138.0054                1729
# Art                  27118.7920    6527.7870                3000
# Binders             203412.7330   30221.7633                5974
# Bookcases           114879.9963   -3472.5560                 868
# Chairs              328449.1030   26590.1663                2356
# Copiers             149528.0300   55617.8249                 234
# Envelopes            16476.4020    6964.1767                 906
# Fasteners             3024.2800     949.5182                 914
# Furnishings          91705.1640   13059.1436                3563
# Labels               12486.3120    5546.2540                1400
# Machines            189238.6310    3384.7569                 440
# Paper                78479.2060   34053.5693                5178
# Phones              330007.0540   44515.7306                3289
# Storage             223843.6080   21278.8264                3158
# Supplies             46673.5380   -1189.0995                 647
# Tables              206965.5320  -17725.4811                1241
#
#               total_pedidos  margem_global  ticket_medio
# Sub-Category
# Accessories             718       0.250547    233.120220
# Appliances              451       0.168675    238.430512
# Art                     731       0.240711     37.098211
# Binders                1316       0.148574    154.568946
# Bookcases               224      -0.030228    512.857126
# Chairs                  576       0.080957    570.224137
# Copiers                  68       0.371956   2198.941618
# Envelopes               249       0.422676     66.170289
# Fasteners               215       0.313965     14.066419
# Furnishings             877       0.142404    104.566892
# Labels                  346       0.444187     36.087607
# Machines                112       0.017886   1689.630634
# Paper                  1191       0.433918     65.893540
# Phones                  814       0.134893    405.414071
# Storage                 777       0.095061    288.087012
# Supplies                187      -0.025477    249.591112
# Tables                  307      -0.085645    674.154827

# %% [markdown]
# ### Interpretação por subcategoria
#
# Tables é a principal causa da baixa eficiência financeira de Furniture, enquanto Bookcases também contribui negativamente. Chairs e Furnishings evitam que a categoria termine com prejuízo, mas não são suficientes para produzir uma margem alta.

# %%
resumo_ano_categoria=resumir_por_grupo(df,['ano','Category'])
resumo_ano_categoria.head(6)
# Out:
#                       faturamento_total  lucro_total  quantidade_vendida  \
# ano  Category
# 2014 Furniture              157192.8531    5457.7255                1623
#      Office Supplies        151776.4120   22593.4161                4569
#      Technology             175278.2330   21492.8325                1389
# 2015 Furniture              170518.2370    3015.2029                1775
#      Office Supplies        137233.4630   25099.5338                4715
#      Technology             162780.8090   33503.8670                1489
#
#                       total_pedidos  margem_global  ticket_medio
# ano  Category
# 2014 Furniture                  353       0.034720    445.305533
#      Office Supplies            746       0.148860    203.453635
#      Technology                 291       0.122621    602.330698
# 2015 Furniture                  371       0.017683    459.617889
#      Office Supplies            778       0.182897    176.392626
#      Technology                 338       0.205822    481.600027

# %% [markdown]
# ### Comparação entre 2014 e 2015 por categoria
#
# Technology foi a principal categoria associada à melhora da margem global em 2015. Mesmo com redução do faturamento, a categoria gerou aproximadamente US$ 12 mil a mais de lucro e aumentou sua margem em 8,32 pontos percentuais. Office Supplies também contribuiu positivamente, enquanto Furniture reduziu parte desse ganho.

# %%
technology=df[df['Category']=='Technology']
technology.head()
# Out:
#     Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 7        8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 11      12  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 19      20  CA-2014-143336 2014-08-27 2014-09-01    Second Class    ZD-21925
# 26      27  CA-2016-121755 2016-01-16 2016-01-20    Second Class    EH-13945
# 35      36  CA-2016-117590 2016-12-08 2016-12-10     First Class    GH-14485
#
#          Customer Name    Segment        Country           City  ...  \
# 7      Brosina Hoffman   Consumer  United States    Los Angeles  ...
# 11     Brosina Hoffman   Consumer  United States    Los Angeles  ...
# 19  Zuschuss Donatelli   Consumer  United States  San Francisco  ...
# 26       Eric Hoffmann   Consumer  United States    Los Angeles  ...
# 35           Gene Hale  Corporate  United States     Richardson  ...
#
#                                         Product Name     Sales Quantity  \
# 7                     Mitel 5320 IP Phone VoIP phone   907.152        6
# 11     Konftel 250 Conference phone - Charcoal black   911.424        4
# 19                           Cisco SPA 501G IP Phone   213.480        3
# 26  Imation 8GB Mini TravelDrive USB 2.0 Flash Drive    90.570        3
# 35                                       GE 30524EE4  1097.544        7
#
#    Discount    Profit dias_envio   ano  mes  margem_lucro  faixa_desconto
# 7       0.2   90.7152          5  2014    6        0.1000   desconto alto
# 11      0.2   68.3568          5  2014    6        0.0750   desconto alto
# 19      0.2   16.0110          5  2014    8        0.0750   desconto alto
# 26      0.0   11.7741          4  2016    1        0.1300    sem desconto
# 35      0.2  123.4737          2  2016   12        0.1125   desconto alto
#
# [5 rows x 26 columns]

# %%
resumo_technology=resumir_por_grupo(technology,['ano', 'Sub-Category'])
resumo_technology
# Out:
#                    faturamento_total  lucro_total  quantidade_vendida  \
# ano  Sub-Category
# 2014 Accessories           25014.272    6402.7150                 580
#      Copiers               10849.782    2912.9433                  29
#      Machines              62023.373     369.1689                  96
#      Phones                77390.806   11808.0053                 684
# 2015 Accessories           40523.960   10197.2752                 635
#      Copiers               26179.450    9930.2988                  63
#      Machines              27763.697    2977.4856                  94
#      Phones                68313.702   10398.8074                 697
# 2016 Accessories           41895.854    9664.2885                 682
#      Copiers               49599.410   17742.7926                  69
#      Machines              55906.886    2907.3180                 129
#      Phones                78962.030    9459.5929                 818
# 2017 Accessories           59946.232   15672.3570                1079
#      Copiers               62899.388   25031.7902                  73
#      Machines              43544.675   -2869.2156                 121
#      Phones               105340.516   12849.3250                1090
#
#                    total_pedidos  margem_global  ticket_medio
# ano  Sub-Category
# 2014 Accessories             140       0.255962    178.673371
#      Copiers                  10       0.268479   1084.978200
#      Machines                 24       0.005952   2584.307208
#      Phones                  149       0.152576    519.401383
# 2015 Accessories             156       0.251636    259.768974
#      Copiers                  20       0.379317   1308.972500
#      Machines                 24       0.107244   1156.820708
#      Phones                  178       0.152221    383.784843
# 2016 Accessories             171       0.230674    245.004994
#      Copiers                  16       0.357722   3099.963125
#      Machines                 32       0.052003   1747.090187
#      Phones                  208       0.119799    379.625144
# 2017 Accessories             251       0.261440    238.829610
#      Copiers                  22       0.397966   2859.063091
#      Machines                 32      -0.065891   1360.771094
#      Phones                  279       0.121979    377.564573

# %% [markdown]
# ### Comparação das subcategorias de Technology entre 2014 e 2015
#
# A melhora de Technology em 2015 foi impulsionada principalmente por Copiers, que apresentou o maior aumento de lucro e margem. Machines também teve uma melhora relevante de eficiência, enquanto Accessories aumentou o lucro principalmente pelo crescimento do faturamento. Phones apresentou redução de lucro e não contribuiu para a melhora da categoria.
